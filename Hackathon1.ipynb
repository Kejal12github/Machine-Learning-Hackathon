# %%
#Code cell <undefined>
# %% [code]
import pandas as pd
import numpy as np

#Code cell <undefined>
# %% [code]
df = pd.read_csv(r"//content//dataset.csv")

#Code cell <undefined>
# %% [code]
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
# %% [code]
df.shape
# Out:
# (920, 16)

# %%
# %% [code]
df['id'].min(), df['id'].max()
# Out:
# (1, 920)

# %%
# %% [code]
df['age'].min(), df['age'].max()
# Out:
# (28, 77)

# %%
#Code cell <undefined>
# %% [code]
df['age'].describe()
# Out:
# count    920.000000
# mean      53.510870
# std        9.424685
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: age, dtype: float64

# %%
#Code cell <undefined>
# %% [code]
import seaborn as sns

#Code cell <undefined>
# %% [code]
custom_colors = ["#FF5733", "#3366FF", "#33FF57"]  # Example colors, you can adjust as needed

#Code cell <undefined>
# %% [code]
sns.histplot(df['age'], kde=True, color="#33FF57", palette=custom_colors)
# Out:
# <ipython-input-10-ee763c754325>:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['age'], kde=True, color="#33FF57", palette=custom_colors)
# <Axes: xlabel='age', ylabel='Count'>

# %%
#Code cell <undefined>
# %% [code]
import matplotlib.pyplot as plt
import seaborn as sns

#Code cell <undefined>
# %% [code]
sns.histplot(df['age'], kde=True)
plt.axvline(df['age'].mean(), color='Red')
plt.axvline(df['age'].median(), color= 'Green')
plt.axvline(df['age'].mode()[0], color='Blue')

# %%
# %% [code]
print('Mean', df['age'].mean())
print('Median', df['age'].median())
print('Mode', df['age'].mode())
# Out:
# Mean 53.51086956521739
# Median 54.0
# Mode 0    54
# Name: age, dtype: int64

# %%
import plotly.express as px

# %% [code]
fig = px.histogram(data_frame=df, x='age', color= 'sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

#Code cell <undefined>
# %% [code]
fig = px.histogram(data_frame=df, x='age', color= 'sex')
fig.show()
#Code cell <undefined>
# %% [code]
df['sex'].value_counts()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Code cell <undefined>
# %% [code]
male_count = 726
female_count = 194
total_count = male_count + female_count
print(total_count)
# Out:
# 920

# %%
#Code cell <undefined>
# %% [code]
male_percentage = (male_count/total_count)*100
female_percentages = (female_count/total_count)*100
print(male_percentage)
print(female_percentages)
# Out:
# 78.91304347826087
# 21.086956521739133

# %%
#Code cell <undefined>
# %% [code]
print(f'Male percentage in the data: {male_percentage:.2f}%')
print(f'Female percentage in the data : {female_percentages:.2f}%')
# Out:
# Male percentage in the data: 78.91%
# Female percentage in the data : 21.09%

# %%
#Code cell <undefined>
# %% [code]
difference_percentage = ((male_count - female_count)/total_count) * 100
print(f'Males are {difference_percentage:.2f}% more than female in the data.')
# Out:
# Males are 57.83% more than female in the data.

# %%
#Code cell <undefined>
# %% [code]
df.groupby('sex')['age'].value_counts()
# Out:
# sex     age
# Female  54     15
#         51     11
#         62     10
#         48      9
#         43      9
#                ..
# Male    77      2
#         76      1
#         33      1
#         28      1
#         31      1
# Name: count, Length: 91, dtype: int64

# %%
#Code cell <undefined>
# %% [code]
df['dataset'].shape[0]
# Out:
# 920

# %%
#Code cell <undefined>
# %% [code]
fig =px.bar(df, x='dataset', color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Code cell <undefined>
# %% [code]
print (df.groupby('sex')['dataset'].value_counts())
# Out:
# sex     dataset
# Female  Cleveland         97
#         Hungary           81
#         Switzerland       10
#         VA Long Beach      6
# Male    Hungary          212
#         Cleveland        207
#         VA Long Beach    194
#         Switzerland      113
# Name: count, dtype: int64

# %%
#Code cell <undefined>
# %% [code]
fig = px.histogram(data_frame=df, x='age', color= 'dataset')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Code cell <undefined>
# %% [code]
print ("Mean of the dataset: ",df['age'].mean())
print ("Median of the dataset: ",df['age'].median())
print ("Mode of the dataset: ",df['age'].mode())
# Out:
# Mean of the dataset:  53.51086956521739
# Median of the dataset:  54.0
# Mode of the dataset:  0    54
# Name: age, dtype: int64

# %%
#Code cell <undefined>
# %% [code]
df['cp'].value_counts()
# Out:
# cp
# asymptomatic       496
# non-anginal        204
# atypical angina    174
# typical angina      46
# Name: count, dtype: int64

# %%
#Code cell <undefined>
# %% [code]
# count plot of cp column by dataset column
sns.countplot(df,x='cp',hue='dataset')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
#Code cell <undefined>
# %% [code]
sns.countplot(df, x='cp', hue= 'sex')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
#Code cell <undefined>
# %% [code]
fig = px.histogram(data_frame=df, x='age', color='cp')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Code cell <undefined>
# %% [code]
df['trestbps'].describe()
# Out:
# count    861.000000
# mean     132.132404
# std       19.066070
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
#Code cell <undefined>
# %% [code]
print(f"Percentage of missing values in trestbps column: {df['trestbps'].isnull().sum() /len(df) *100:.2f}%")
# Out:
# Percentage of missing values in trestbps column: 6.41%

# %%
#Code cell <undefined>
# %% [code]
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#Code cell <undefined>
# %% [code]
imputer1 = IterativeImputer(max_iter=10, random_state=42)

#Code cell <undefined>
# %% [code]
# Fit the imputer on trestbps column
imputer1.fit(df[['trestbps']])
# Out:
# IterativeImputer(random_state=42)

# %%
#Code cell <undefined>
# %% [code]
# Transform the data
df['trestbps'] = imputer1.transform(df[['trestbps']])

#Code cell <undefined>
# %% [code]
# Check the missing values in trestbps column
print(f"Missing values in trestbps column: {df['trestbps'].isnull().sum()}")
# Out:
# Missing values in trestbps column: 0

# %%
#Code cell <undefined>
# %% [code]
# First lets see data types or category of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  920 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
#Code cell <undefined>
# %% [code]
# let's see which columns has missing values
(df.isnull().sum()/ len(df)* 100).sort_values(ascending=False)
# Out:
# ca          66.413043
# thal        52.826087
# slope       33.586957
# fbs          9.782609
# oldpeak      6.739130
# thalch       5.978261
# exang        5.978261
# chol         3.260870
# restecg      0.217391
# id           0.000000
# age          0.000000
# sex          0.000000
# dataset      0.000000
# cp           0.000000
# trestbps     0.000000
# num          0.000000
# dtype: float64

# %%
#Code cell <undefined>
# %% [code]
# create an object of iterative imputer
imputer2 = IterativeImputer(max_iter=10, random_state=42)

#Code cell <undefined>
# %% [code]
(df.isnull().sum()/ len(df)* 100).sort_values(ascending=False)
# Out:
# ca          66.413043
# thal        52.826087
# slope       33.586957
# fbs          9.782609
# oldpeak      6.739130
# thalch       5.978261
# exang        5.978261
# chol         3.260870
# restecg      0.217391
# id           0.000000
# age          0.000000
# sex          0.000000
# dataset      0.000000
# cp           0.000000
# trestbps     0.000000
# num          0.000000
# dtype: float64

# %%
df['thal'].value_counts()
# Out:
# thal
# normal               196
# reversable defect    192
# fixed defect          46
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#       id  age     sex        dataset               cp    trestbps   chol  \
# 915  916   54  Female  VA Long Beach     asymptomatic  127.000000  333.0
# 916  917   62    Male  VA Long Beach   typical angina  132.132404  139.0
# 917  918   55    Male  VA Long Beach     asymptomatic  122.000000  223.0
# 918  919   58    Male  VA Long Beach     asymptomatic  132.132404  385.0
# 919  920   62    Male  VA Long Beach  atypical angina  120.000000  254.0
#
#        fbs           restecg  thalch  exang  oldpeak slope  ca          thal  \
# 915   True  st-t abnormality   154.0  False      0.0   NaN NaN           NaN
# 916  False  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN
# 917   True  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect
# 918   True    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN
# 919  False    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN
#
#      num
# 915    1
# 916    0
# 917    2
# 918    0
# 919    1

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps      0
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
#Code cell <undefined>
# %% [code]
missing_data_cols = df.isnull().sum()[df.isnull().sum()>0].index.tolist()

#Code cell <undefined>
# %% [code]
missing_data_cols
# Out:
# ['chol', 'fbs', 'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %%
#Code cell <undefined>
# %% [code]
cat_cols = df.select_dtypes(include='object').columns.tolist()
cat_cols
# Out:
# ['sex', 'dataset', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']

# %%
#Code cell <undefined>
# %% [code]
Num_cols = df.select_dtypes(exclude='object').columns.tolist()
Num_cols
# Out:
# ['id', 'age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'num']

# %%
#Code cell <undefined>
# %% [code]
print(f'categorical Columns: {cat_cols}')
print(f'numerical Columns: {Num_cols}')
# Out:
# categorical Columns: ['sex', 'dataset', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']
# numerical Columns: ['id', 'age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'num']

# %%
#Code cell <undefined>
# %% [code]
print(f'categorical Columns: {cat_cols}')
print(f'numerical Columns: {Num_cols}')
# Out:
# categorical Columns: ['sex', 'dataset', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']
# numerical Columns: ['id', 'age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'num']

# %%
#Code cell <undefined>
# %% [code]

categorical_cols = ['thal', 'ca', 'slope', 'exang', 'restecg','thalch', 'chol', 'trestbps']
bool_cols = ['fbs']
numerical_cols = ['oldpeak','age','restecg','fbs', 'cp', 'sex', 'num']


#Code cell <undefined>
# %% [code]
# This function imputes missing values in categorical columnsdef impute_categorical_missing_data(passed_col):
passed_col = categorical_cols
def impute_categorical_missing_data(wrong_col):
  df_null = df[df[passed_col].isnull()]
  df_not_null = df[df[passed_col].notnull()]

  X = df_not_null.drop(passed_col, axis=1)
  y = df_not_null[passed_col]

# %%
df_not_null = df[df[passed_col].notnull()]
X = df_not_null.drop(passed_col, axis=1)
#Code cell <undefined>
# %% [code]

X.head()
# Out:
#    id  age  sex dataset   cp  fbs  oldpeak  num
# 0 NaN  NaN  NaN     NaN  NaN  NaN      NaN  NaN
# 1 NaN  NaN  NaN     NaN  NaN  NaN      NaN  NaN
# 2 NaN  NaN  NaN     NaN  NaN  NaN      NaN  NaN
# 3 NaN  NaN  NaN     NaN  NaN  NaN      NaN  NaN
# 4 NaN  NaN  NaN     NaN  NaN  NaN      NaN  NaN

# %%
df_null = df[df[passed_col].isnull()]
y = df_not_null[passed_col]

#Code cell <undefined>
# %% [code]
y.head()
# Out:
#                 thal   ca        slope  exang         restecg  thalch   chol  \
# 0       fixed defect  0.0  downsloping  False  lv hypertrophy   150.0  233.0
# 1             normal  3.0         flat   True  lv hypertrophy   108.0  286.0
# 2  reversable defect  2.0         flat   True  lv hypertrophy   129.0  229.0
# 3             normal  0.0  downsloping  False          normal   187.0  250.0
# 4             normal  0.0    upsloping  False  lv hypertrophy   172.0  204.0
#
#    trestbps
# 0     145.0
# 1     160.0
# 2     120.0
# 3     130.0
# 4     130.0

# %%
#Code cell <undefined>
# %% [code]
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor
import numpy as np
other_missing_cols = [col for col in missing_data_cols if col != passed_col]
label_encoder = LabelEncoder()
onehotencoder = OneHotEncoder(sparse=False)
for col in y.columns:
    if y[col].dtype == 'object':
        # Reshape Series to 2D array
        y[col] = onehotencoder.fit_transform(y[[col]])
if passed_col in bool_cols:
    y = label_encoder.fit_transform(y)
imputer = IterativeImputer(estimator=RandomForestRegressor(random_state=16), add_indicator=True)
for col in other_missing_cols:
    if col in y.columns:
        cols_with_missing_values = y[[col]].values  # Ensure we have a 2D array
        imputed_values = imputer.fit_transform(cols_with_missing_values)
        X[col] = imputed_values[:, 0]  # Replace missing values in X


#Code cell <undefined>
# %% [code]
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# Create an imputer for numerical features (you can choose different strategies like 'mean', 'median', or 'most_frequent')
imputer = SimpleImputer(strategy='mean')

# Apply the imputer to the dataset
X_imputed = imputer.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Initialize the RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)  # Set a random state for reproducibility

# Train the classifier
rf_classifier.fit(X_train, y_train)

# Predict on the test set
y_pred = rf_classifier.predict(X_test)

# Calculate accuracy score
acc_score = accuracy_score(y_test, y_pred)

# Print the accuracy score
print("The feature '" + passed_col + "' has been imputed with", round((acc_score * 100), 2), "accuracy\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#
# <ipython-input-75-5cdc6938b6e6>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#
# <ipython-input-75-5cdc6938b6e6>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.info()

df.columns

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  920 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# ...

# %%
# split the data into X and y
X= df.drop('num', axis=1)
Y = df['num']
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
# Assuming Y is your DataFrame
label_encoders = {}
onehot_encoders = {}

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# Assume df is your DataFrame and 'num' is the column with categorical data
Y = df['num']

# Initialize dictionaries for label encoders and one-hot encoders
label_encoders = {}
onehot_encoders = {}

# Convert Y to DataFrame if it's a Series
Y = Y.to_frame()

# Loop through each column in Y
for col in Y.columns:
    if Y[col].dtype == 'object':
        # Initialize and apply LabelEncoder
        label_encoders[col] = LabelEncoder()
        Y[col] = label_encoders[col].fit_transform(Y[col].astype(str))

        # Initialize and apply OneHotEncoder
        onehot_encoders[col] = OneHotEncoder(sparse=False)
        encoded = onehot_encoders[col].fit_transform(Y[[col]])

        # Create a DataFrame with the OneHotEncoded values and join it with Y
        encoded_df = pd.DataFrame(encoded, columns=[f"{col}_{category}" for category in label_encoders[col].classes_])
        Y = Y.join(encoded_df)

        # Drop the original column as it's been one-hot encoded
        Y.drop(columns=[col], inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Assuming `Y` contains encoded categorical columns

# Inverse transform for Label Encoding
for col, le in label_encoders.items():
    Y[col] = le.inverse_transform(Y[col])

# For OneHotEncoding inverse transform
# Note: OneHotEncoder does not support inverse_transform directly; you need to reconstruct the original column.
for col, ohe in onehot_encoders.items():
    # Find the one-hot encoded columns
    encoded_columns = [c for c in Y.columns if c.startswith(f"{col}_")]

    # Reconstruct the original column from one-hot encoded columns
    if encoded_columns:
        # Get one-hot encoded data
        encoded_data = Y[encoded_columns].values

        # Use the original one-hot encoder to predict the column values
        reconstructed_col = ohe.inverse_transform(encoded_data)

        # Add the reconstructed column to the DataFrame
        Y[col] = reconstructed_col.ravel()

        # Drop the one-hot encoded columns
        Y.drop(columns=encoded_columns, inplace=True)

# Ensure X is properly defined and corresponds to your feature columns
# Example: X = df.drop(columns=['num'])

# Split the data into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
# Import all models.
from sklearn.linear_model import LogisticRegression  # Corrected class name and import
from sklearn.neighbors import KNeighborsClassifier  # Corrected class name and import
from sklearn.svm import SVC  # Corrected class name and import
from sklearn.tree import DecisionTreeClassifier  # Corrected class name and import
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier  # Corrected class names and import
from xgboost import XGBClassifier  # Corrected class name and import
from lightgbm import LGBMClassifier  # Added correct class import
from sklearn.naive_bayes import GaussianNB  # Corrected class name and import

# Importing pipeline
from sklearn.pipeline import Pipeline  # Corrected class name

# Import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
#
#
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.

# %%
# Create a list of models to evaluate
models = [
    ('Logistic Regression', LogisticRegression(random_state=42)),  # Corrected class name and parameter
    ('Gradient Boosting', GradientBoostingClassifier(random_state=42)),  # Corrected class name
    ('KNeighbors Classifier', KNeighborsClassifier()),  # Corrected class name
    ('Decision Tree Classifier', DecisionTreeClassifier(random_state=42)),  # Corrected class name and parameter
    ('AdaBoost Classifier', AdaBoostClassifier(random_state=42)),  # Corrected class name and parameter
    ('Random Forest', RandomForestClassifier(random_state=42)),  # Corrected class name and parameter
    ('XGBoost Classifier', XGBClassifier(random_state=42)),  # Corrected class name and parameter
    ('Support Vector Machine', SVC(random_state=42)),  # Corrected class name
    ('Naive Bayes Classifier', GaussianNB())  # Corrected class name
]

best_model = None
best_accuracy = 0.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Iterate over the models and evaluate their performance
for name, model in models:
    try:
        # Create a pipeline for each model
        pipeline = Pipeline([
            # Uncomment and configure these steps if necessary
            # ('imputer', SimpleImputer(strategy='most_frequent')),
            # ('encoder', OneHotEncoder(handle_unknown='ignore')),
            ('model', model)  # Correctly use model object
        ])

        # Perform cross-validation
        scores = cross_val_score(pipeline, X_train, Y_train, cv=5, error_score='raise')  # Debugging option

        # Calculate mean accuracy
        mean_accuracy = scores.mean()

        # Fit the pipeline on the training data
        pipeline.fit(X_train, Y_train)

        # Make prediction on the test data
        Y_pred = pipeline.predict(X_test)

        # Calculate accuracy score
        accuracy = accuracy_score(Y_test, Y_pred)

        # Print performance metrics
        print(f"Model: {name}")
        print(f"Cross-validation Accuracy: {mean_accuracy:.4f}")
        print(f"Test Accuracy: {accuracy:.4f}")
        print()

    except ValueError as e:
        print(f"Model: {name} encountered an error.")
        print(f"Error details: {e}")
        print()
# Out:
# Model: Logistic Regression encountered an error.
# Error details: could not convert string to float: 'Male'
#
# Model: Gradient Boosting encountered an error.
# Error details: could not convert string to float: 'Male'
#
# Model: KNeighbors Classifier encountered an error.
# Error details: could not convert string to float: 'Male'
#
# Model: Decision Tree Classifier encountered an error.
# Error details: could not convert string to float: 'Male'
#
# Model: AdaBoost Classifier encountered an error.
# Error details: Input contains NaN
#
# Model: Random Forest encountered an error.
# Error details: could not convert string to float: 'Male'
#
# Model: XGBoost Classifier encountered an error.
# ...

# %%
 from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# Iterate over the models and evaluate their performance
for name, model in models:
    # Create a pipeline for each model
    pipeline = Pipeline([
        # Uncomment and correct if needed
        # ('imputer', SimpleImputer(strategy='most_frequent')),
        # ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ('model', model)  # Use model object instead of name
    ])

    try:
        # Perform cross-validation
        scores = cross_val_score(pipeline, X_train, Y_train, cv=5)

        # Calculate mean accuracy
        mean_accuracy = scores.mean()

        # Fit the pipeline on the training data
        pipeline.fit(X_train, Y_train)

        # Make predictions on the test data
        Y_pred = pipeline.predict(X_test)

        # Calculate accuracy score
        accuracy = accuracy_score(Y_test, Y_pred)

        # Print the performance metrics
        print("Model:", name)
        print("Cross Validation Accuracy:", mean_accuracy)  # Print mean accuracy
        print("Test Accuracy:", accuracy)  # Print test accuracy
        print()

    except Exception as e:
        print(f"Model {name} failed with error: {e}")
# Out:
# Model Logistic Regression failed with error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1152, in wrapper
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# Initialize variables to keep track of the best model
best_model = None
best_accuracy = 0.0

# Iterate over the models and evaluate their performance
for name, model in models:
    # Create a pipeline for each model
    pipeline = Pipeline([
        # Uncomment and correct if needed
        # ('imputer', SimpleImputer(strategy='most_frequent')),
        # ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ('model', model)  # Use model object instead of name
    ])

    try:
        # Perform cross-validation
        scores = cross_val_score(pipeline, X_train, Y_train, cv=5)

        # Calculate mean accuracy
        mean_accuracy = scores.mean()

        # Fit the pipeline on the training data
        pipeline.fit(X_train, Y_train)

        # Make predictions on the test data
        Y_pred = pipeline.predict(X_test)

        # Calculate accuracy score
        accuracy = accuracy_score(Y_test, Y_pred)

        # Print the performance metrics
        print("Model:", name)
        print("Cross Validation Accuracy:", mean_accuracy)  # Print mean accuracy
        print("Test Accuracy:", accuracy)  # Print test accuracy
        print()

        # Check if the current model has the best accuracy
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model = pipeline

    except Exception as e:
        print(f"Model {name} failed with error: {e}")

# Print the best model and its accuracy
print("Best Model:", best_model)
print("Best Accuracy:", best_accuracy)
# Out:
# Model Logistic Regression failed with error:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1152, in wrapper
# ...

# %%
# Retrieve the best model
print("Best Model:", best_model)

categorical_cols = ['thal', 'ca', 'slope', 'exang', 'restecg', 'fbs', 'cp', 'sex', 'num']
# Out:
# Best Model: None

# %%
def evaluate_classification_models(X, y, categorical_columns):
    # Encode categorical columns
    X_encoded = X.copy()
    label_encoders = {}
    for col in categorical_columns:  # Changed 'cols' to 'col'
        X_encoded[col] = LabelEncoder().fit_transform(X_encoded[col])  # Changed 'onehotencoder' to 'LabelEncoder'

    # Split data into train and test sets
    X_train, X_val, Y_train, Y_val = train_test_split(X_encoded, Y, test_size=0.2, random_state=42)  # Corrected parameter names

# %%
        # Define models
        models = {
        "Logistic Regression": LogisticRegression(),
        "KNN": KNeighborsClassifier(),  # Corrected class name
        "NB": GaussianNB(),  # Corrected class name
        "SVM": SVC(),  # Corrected class name
        "Decision Tree": DecisionTreeClassifier(),  # Corrected class name
        "Random Forest": RandomForestClassifier(),  # Corrected class name
        "XGBoost": XGBClassifier(),  # Corrected class name
        "GradientBoosting": GradientBoostingClassifier(),  # Corrected class name
        "AdaBoost": AdaBoostClassifier()  # Corrected class name and removed extra parenthesis
       }

# %%
def evaluate_classification_models(X_train, Y_train, X_val, Y_val, models):
    # Initialize dictionary to store results and variables for the best model
    results = {}
    best_model = None
    best_accuracy = 0.0

    # Iterate over each model
    for name, model in models.items():
        # Fit the model on the training data
        model.fit(X_train, Y_train)

        # Predict on the validation set
        Y_pred = model.predict(X_val)

        # Calculate accuracy score
        accuracy = accuracy_score(Y_val, Y_pred)

        # Store results in dictionary
        results[name] = accuracy

        # Update best model if the current model is better
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model = name

    return results, best_model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression  # Replace with your model

# Define the categorical columns and target variable
categorical_cols = ['thal', 'ca', 'slope', 'exang', 'restecg', 'fbs', 'cp', 'sex']
target_col = 'num'

# Select features and target variable
X = df[categorical_cols]  # Features
Y = df[target_col]  # Target variable

# Encode target variable
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
Y_encoded = label_encoder.fit_transform(Y)

# Split the data into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X, Y_encoded, test_size=0.2, random_state=42)

# Define the preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), categorical_cols)  # Apply one-hot encoding to categorical columns
    ],
    remainder='passthrough'  # Leave other columns unchanged
)

# Define the model pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())  # Replace with your model
])

# Train the model
pipeline.fit(X_train, Y_train)

# Predict on validation set
Y_pred = pipeline.predict(X_val)

# Evaluate model performance
accuracy = accuracy_score(Y_val, Y_pred)
print("Validation Accuracy:", accuracy)

# Evaluate multiple models
def evaluate_classification_models(X_train, Y_train, X_val, Y_val, models):
    results = {}
    best_model = None
    best_accuracy = 0.0
    for name, model in models.items():
        # Create a pipeline for each model
        pipeline = Pipeline([
            ('preprocessor', ColumnTransformer(
                transformers=[
                    ('cat', OneHotEncoder(), categorical_cols)  # Apply one-hot encoding to categorical columns
                ],
                remainder='passthrough'
            )),
            ('model', model)
        ])
        # Train the model
        pipeline.fit(X_train, Y_train)
        # Predict on validation set
        Y_pred = pipeline.predict(X_val)
        # Calculate accuracy
        accuracy = accuracy_score(Y_val, Y_pred)
        results[name] = accuracy
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model = name

    return results, best_model

# Define models dictionary
models = {
    "Logistic Regression": LogisticRegression(),  # Replace with your model
    # Add other models here
}

# Evaluate models
results, best_model = evaluate_classification_models(X_train, Y_train, X_val, Y_val, models)

# Print the performance metrics
print("Model accuracies:", results)
print("Best model:", best_model)
# Out:
# Validation Accuracy: 0.5760869565217391
# Model accuracies: {'Logistic Regression': 0.5760869565217391}
# Best model: Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

def hyperparameter_tuning(X, Y, categorical_columns, models):
    # Define dictionary to store results
    results = {}

    # Encode categorical columns
    X_encoded = X.copy()
    for col in categorical_columns:
        X_encoded[col] = LabelEncoder().fit_transform(X_encoded[col])

    # Split data into train and validation sets
    X_train, X_val, Y_train, Y_val = train_test_split(X_encoded, Y, test_size=0.2, random_state=42)

    # Perform hyperparameter tuning for each model
    for model_name, model in models.items():
        # Define parameter grid for hyperparameter tuning
        param_grid = {}
        if model_name == 'Logistic Regression':
            param_grid = {'C': [0.1, 1, 10, 100]}
        elif model_name == 'KNN':
            param_grid = {'n_neighbors': [3, 5, 7, 9]}
        elif model_name == 'NB':
            param_grid = {'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6]}
        elif model_name == 'SVM':
            param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [0.1, 1, 10, 100]}
        elif model_name == 'Decision Tree':
            param_grid = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10]}
        elif model_name == 'Random Forest':
            param_grid = {'n_estimators': [100, 200, 300], 'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10]}
        elif model_name == 'XGBoost':
            param_grid = {'learning_rate': [0.01, 0.1, 0.2], 'n_estimators': [100, 200, 300], 'max_depth': [3, 5, 7]}
        elif model_name == 'GradientBoosting':
            param_grid = {'learning_rate': [0.01, 0.1, 0.2], 'n_estimators': [100, 200, 300], 'max_depth': [3, 5, 7]}
        elif model_name == 'AdaBoost':
            param_grid = {'learning_rate': [0.01, 0.1, 0.2], 'n_estimators': [50, 100, 200]}

        # Perform hyperparameter tuning using GridSearchCV
        grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
        grid_search.fit(X_train, Y_train)
         # Get best hyperparameters and evaluate on validation set
        best_params = grid_search.best_params_
        best_model = grid_search.best_estimator_
        Y_pred = best_model.predict(X_val)
        accuracy = accuracy_score(Y_val, Y_pred)

        # Store results in dictionary
        results[model_name] = {'best_params': best_params, 'accuracy': accuracy}

        return results

# Define models dictionary
models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "NB": GaussianNB(),
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "XGBoost": XGBClassifier(),
    "GradientBoosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier()
}

# Example usage:
results = hyperparameter_tuning(X, y, categorical_cols, models)
for model_name, result in results.items():
    print("Model:", model_name)
    print("Best hyperparameters:", result['best_params'])
    print("Accuracy:", result['accuracy'])
    print()
# Out:
# Model: Logistic Regression
# Best hyperparameters: {'C': 0.1}
# Accuracy: 0.5434782608695652
